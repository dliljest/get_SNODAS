# %%
import processSNODAS_points
import importlib

# %%
importlib.reload(processSNODAS_points)
# Out:
# <module 'processSNODAS' from '/uufs/chpc.utah.edu/common/home/civil-group1/NSM/SNODAS/WY2019/processSNODAS.py'>

# %%
months =  ["01_Jan", "02_Feb", "03_Mar", "04_Apr", "05_May", "06_Jun", "07_Jul", "08_Aug", "09_Sep"]

for month in months:
    if __name__ == "__main__":
        source_directory = f"/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/data/2019/{month}/extracted/tiffs"
        destination_directory = "/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/weekdata"

        processSNODAS_points.copy_tif_files(source_directory, destination_directory, 'w')
# Out:
# File 'us_swe_20190107_.tif' copied to '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/weekdata'
# File 'us_swe_20190114_.tif' copied to '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/weekdata'
# File 'us_swe_20190121_.tif' copied to '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/weekdata'
# File 'us_swe_20190128_.tif' copied to '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/weekdata'
# File 'us_swe_20190204_.tif' copied to '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/weekdata'
# File 'us_swe_20190211_.tif' copied to '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/weekdata'
# File 'us_swe_20190218_.tif' copied to '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/weekdata'
# File 'us_swe_20190225_.tif' copied to '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/weekdata'
# ...

# %%
# HDF5 file
h5_file_path = '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/domain/predictions2018-09-24.h5'
output_dir = f"/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/domain"

dataset_keys = ['N_Sierras',
               'S_Sierras_High',
               'S_Sierras_Low',
               'Greater_Yellowstone',
               'N_Co_Rockies',
               'SW_Mont',
               'SW_Co_Rockies',
               'GBasin',
               'N_Wasatch',
               'N_Cascade',
               'S_Wasatch',
               'SW_Mtns',
               'E_WA_N_Id_W_Mont',
               'S_Wyoming',
               'SE_Co_Rockies',
               'Sawtooth',
               'Ca_Coast',
               'E_Or',
               'N_Yellowstone',
               'S_Cascade',
               'Wa_Coast',
               'Greater_Glacier',
               'Or_Coast'
              ]

processSNODAS_points.point_preprocess(h5_file_path,dataset_keys,output_dir)
# Out:
# [                                            Long        Lat  \
#  cell_id
#  0013ea8d-f647-4664-b40f-57bb96f800e5 -121.310593  39.779513
#  001476f9-a9d5-4128-8210-e2c4879ce505 -120.753637  39.391823
#  00270da4-a790-4b81-a693-e1e8c4f13e6e -121.301610  39.551315
#  00325ba7-fcbe-4bab-8c4f-f70cfe80ea46 -121.310593  40.295338
#  003ca3a3-c298-4253-9f1b-7f6a1a097ca6 -119.963120  39.329313
#  ...                                          ...        ...
#  ffbaa1a5-6e6c-47ab-b432-841932bfcf8e -121.139913  39.634384
#  ffbecb71-8bc4-44fe-80b6-7e46d5a62813 -121.086014  40.343283
#  ffdb8d1c-7704-4a87-a22f-a68881cf9510 -121.544155  39.869202
#  ffeef29b-979e-4c1b-9ca6-a7ce0944af09 -121.202795  40.466412
#  ffefd240-fae9-4ab2-8821-75ea2bad321d -120.906351  40.089476
#
#                                                           geometry
#  cell_id
#  0013ea8d-f647-4664-b40f-57bb96f800e5  POINT (-121.31059 39.77951)
#  001476f9-a9d5-4128-8210-e2c4879ce505  POINT (-120.75364 39.39182)
# ...

# %%
tif_folder_path = '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/Plot_Dates'
csv_folder_path = '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/domain/by_region'
output_csv_folder_path = '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/Figure_dev/by_region/SNODAS'


processSNODAS_points.extract_values_from_tif_REGION(tif_folder_path, csv_folder_path, output_csv_folder_path)
# Out:
# N_Sierras_COORDS.csv
#                                             Long        Lat  2018-10-02  \
# cell_id
# 0013ea8d-f647-4664-b40f-57bb96f800e5 -121.310593  39.779513         0.0
# 001476f9-a9d5-4128-8210-e2c4879ce505 -120.753637  39.391823         0.0
# 00270da4-a790-4b81-a693-e1e8c4f13e6e -121.301610  39.551315         0.0
# 00325ba7-fcbe-4bab-8c4f-f70cfe80ea46 -121.310593  40.295338         0.0
# 003ca3a3-c298-4253-9f1b-7f6a1a097ca6 -119.963120  39.329313         0.0
# ...                                          ...        ...         ...
# ffbaa1a5-6e6c-47ab-b432-841932bfcf8e -121.139913  39.634384         0.0
# ffbecb71-8bc4-44fe-80b6-7e46d5a62813 -121.086014  40.343283         0.0
# ffdb8d1c-7704-4a87-a22f-a68881cf9510 -121.544155  39.869202         0.0
# ffeef29b-979e-4c1b-9ca6-a7ce0944af09 -121.202795  40.466412         0.0
# ffefd240-fae9-4ab2-8821-75ea2bad321d -120.906351  40.089476         0.0
#
# ...

# %%
folder_path = '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/Figure_dev/by_region/SNODAS'
pickle_file_path = '/uufs/chpc.utah.edu/common/home/u1320286/civil-group1/NSM/SNODAS/WY2019/Figure_dev/by_region/SNODAS/SNODAS_WY2019.pkl'

processSNODAS_points.combine_csv_files(folder_path, pickle_file_path)
